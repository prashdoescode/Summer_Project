# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from DataTransformation import LowPassFilter, PrincipalComponentAnalysis

# %%
from TemporalAbstraction import NumericalAbstraction

# %%
df = pd.read_pickle("../../data/interim/02_outliers_removed_chauvenets.pkl")

# %%
predictor_columns = list(df.columns[:6])

# %%
plt.style.use("fivethirtyeight")
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams["figure.dpi"] = 100
plt.rcParams["lines.linewidth"] = 2

# %%
for col in predictor_columns:
    df[col] = df[col].interpolate()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   acc_x        9009 non-null   float64
#  1   acc_y        9009 non-null   float64
#  2   acc_z        9009 non-null   float64
#  3   gyr_x        9009 non-null   float64
#  4   gyr_y        9009 non-null   float64
#  5   gyr_z        9009 non-null   float64
#  6   participant  9009 non-null   object
#  7   label        9009 non-null   object
#  8   category     9009 non-null   object
#  9   set          9009 non-null   int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 774.2+ KB

# %%
df[df["set"]== 25]["acc_y"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
df[df["set"]== 50]["acc_y"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
duration = df[df["set"] == 1].index[-1] - df[df["set"] ==1].index[0]

# %%
duration.seconds
# Out:
# 16

# %%
for s in df["set"].unique():
    
    start = df[df["set"] == s].index[0]
    stop = df[df["set"] == s].index[-1]
      
    duration = stop - start
    df.loc[(df["set"]== s),"duration"] = duration.seconds

# %%
duration_df = df.groupby(["category"])["duration"].mean()

# %%
duration_df.iloc[0] /5
# Out:
# np.float64(2.9487001733102254)

# %%
duration_df.iloc[1] /10
# Out:
# np.float64(2.4942528735632186)

# %%
df_lowpass = df.copy()

# %%
LowPass = LowPassFilter()

# %%
fs  = 1000/200

# %%
cutoff = 1.3

# %%
df_lowpass = LowPass.low_pass_filter(df_lowpass,"acc_y",fs, cutoff, order=5)

# %%
subset = df_lowpass[df_lowpass["set"] == 45]

# %%
print(subset["label"][0])
# Out:
# ohp
# <ipython-input-26-823db250493d>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(subset["label"][0])

# %%
fig,ax = plt.subplots(nrows=2, sharex=True, figsize=(20,10))
ax[0].plot(subset["acc_y"].reset_index(drop=True), label="raw data")
ax[1].plot(subset["acc_y_lowpass"].reset_index(drop=True), label="butterworth filter")
ax[0].legend(loc="upper center", bbox_to_anchor=(0.5,1.15), fancybox=True, shadow=True)
ax[1].legend(loc="upper center", bbox_to_anchor=(0.5,1.15), fancybox=True, shadow=True)

# %%
for col in predictor_columns:
    df_lowpass = LowPass.low_pass_filter(df_lowpass,col,fs, cutoff, order=5)
    df_lowpass[col] = df_lowpass[col + "_lowpass"]
    del df_lowpass[col + "_lowpass"]

# %%
df_pca = df_lowpass.copy()

# %%
PCA = PrincipalComponentAnalysis()

# %%
pc_values = PCA.determine_pc_explained_variance(df_pca,predictor_columns)

# %%
plt.figure(figsize=(10,10))
plt.plot(range(1,len(predictor_columns) + 1),pc_values)
plt.xlabel("principal component number")
plt.ylabel("explained variance")
plt.show()

# %%
df_pca = PCA.apply_pca(df_pca,predictor_columns,3)

# %%
subset = df_pca[df_pca["set"] == 35]

# %%
subset[["pca_1","pca_2","pca_3"]].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
df_squared = df_pca.copy()

# %%
acc_r = df_squared["acc_x"] ** 2 + df_squared["acc_y"] ** 2 + df_squared["acc_z"] ** 2

# %%
gyr_r = df_squared["gyr_x"] ** 2 + df_squared["gyr_y"] ** 2 + df_squared["gyr_z"] ** 2

# %%
df_squared["acc_r"] = np.sqrt(acc_r)

# %%
df_squared["gyr_r"] = np.sqrt(gyr_r)

# %%
subset = df_squared[df_squared["set"] == 14]

# %%
subset[["acc_r","gyr_r"]].plot(subplots=True)
# Out:
# array([<Axes: xlabel='epoch (ms)'>, <Axes: xlabel='epoch (ms)'>],
#       dtype=object)

# %%
df_squared
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  duration  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30      16.0
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30      16.0
# ...                           ...         ...    ...      ...  ...       ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90      19.0
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90      19.0
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90      19.0
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90      19.0
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90      19.0
#
#                             pca_1     pca_2     pca_3     acc_r     gyr_r
# epoch (ms)
# 2019-01-11 15:08:05.200  0.315889 -0.075461  0.072243  0.979672  3.222503
# 2019-01-11 15:08:05.400  0.314873 -0.073888  0.069825  0.975474  0.600176
# 2019-01-11 15:08:05.600  0.314236 -0.080343  0.066219  0.969585  4.948974
# 2019-01-11 15:08:05.800  0.314356 -0.090852  0.061839  0.966278  5.903203
# 2019-01-11 15:08:06.000  0.313630 -0.097479  0.062974  0.964693  2.293593
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.349351 -0.148450 -0.053031  0.991076  4.508719
# 2019-01-20 17:33:27.200 -0.371610 -0.151455 -0.058498  1.056234  4.289212
# 2019-01-20 17:33:27.400 -0.368098 -0.153153 -0.058772  1.047919  2.329568
# 2019-01-20 17:33:27.600 -0.356453 -0.149165 -0.057320  1.013660  3.895260
# 2019-01-20 17:33:27.800 -0.365317 -0.148295 -0.057171  1.037636  4.281944
#
# [9009 rows x 16 columns]

# %%
df_temporal = df_squared.copy()

# %%
df_temporal
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  duration  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30      16.0
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30      16.0
# ...                           ...         ...    ...      ...  ...       ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90      19.0
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90      19.0
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90      19.0
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90      19.0
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90      19.0
#
#                             pca_1     pca_2     pca_3     acc_r     gyr_r
# epoch (ms)
# 2019-01-11 15:08:05.200  0.315889 -0.075461  0.072243  0.979672  3.222503
# 2019-01-11 15:08:05.400  0.314873 -0.073888  0.069825  0.975474  0.600176
# 2019-01-11 15:08:05.600  0.314236 -0.080343  0.066219  0.969585  4.948974
# 2019-01-11 15:08:05.800  0.314356 -0.090852  0.061839  0.966278  5.903203
# 2019-01-11 15:08:06.000  0.313630 -0.097479  0.062974  0.964693  2.293593
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.349351 -0.148450 -0.053031  0.991076  4.508719
# 2019-01-20 17:33:27.200 -0.371610 -0.151455 -0.058498  1.056234  4.289212
# 2019-01-20 17:33:27.400 -0.368098 -0.153153 -0.058772  1.047919  2.329568
# 2019-01-20 17:33:27.600 -0.356453 -0.149165 -0.057320  1.013660  3.895260
# 2019-01-20 17:33:27.800 -0.365317 -0.148295 -0.057171  1.037636  4.281944
#
# [9009 rows x 16 columns]

# %%
NumAbs = NumericalAbstraction()

# %%
predictor_columns = predictor_columns + ["acc_r","gyr_r"]

# %%
df_temporal
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  duration  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30      16.0
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30      16.0
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30      16.0
# ...                           ...         ...    ...      ...  ...       ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90      19.0
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90      19.0
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90      19.0
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90      19.0
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90      19.0
#
#                             pca_1     pca_2     pca_3     acc_r     gyr_r
# epoch (ms)
# 2019-01-11 15:08:05.200  0.315889 -0.075461  0.072243  0.979672  3.222503
# 2019-01-11 15:08:05.400  0.314873 -0.073888  0.069825  0.975474  0.600176
# 2019-01-11 15:08:05.600  0.314236 -0.080343  0.066219  0.969585  4.948974
# 2019-01-11 15:08:05.800  0.314356 -0.090852  0.061839  0.966278  5.903203
# 2019-01-11 15:08:06.000  0.313630 -0.097479  0.062974  0.964693  2.293593
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.349351 -0.148450 -0.053031  0.991076  4.508719
# 2019-01-20 17:33:27.200 -0.371610 -0.151455 -0.058498  1.056234  4.289212
# 2019-01-20 17:33:27.400 -0.368098 -0.153153 -0.058772  1.047919  2.329568
# 2019-01-20 17:33:27.600 -0.356453 -0.149165 -0.057320  1.013660  3.895260
# 2019-01-20 17:33:27.800 -0.365317 -0.148295 -0.057171  1.037636  4.281944
#
# [9009 rows x 16 columns]

# %%
ws = 1000/200

# %%
ws = int(1000/200)

# %%
ws
# Out:
# 5

# %%
predictor_columns
# Out:
# ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z', 'acc_r', 'gyr_r']

# %%
for col in predictor_columns:
    df_temporal = NumAbs.abstract_numerical(df_temporal, [col], ws, "mean")
    df_temporal = NumAbs.abstract_numerical(df_temporal, [col], ws, "std")

# %%
df_temporal
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  ...  \
# epoch (ms)                                                          ...
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30  ...
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30  ...
# ...                           ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90  ...
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90  ...
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90  ...
#
#                          gyr_x_temp_mean_ws_5  gyr_x_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              1.522572             2.602489
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000            -11.989659            18.259425
# 2019-01-20 17:33:27.200             -4.824823            12.436925
# 2019-01-20 17:33:27.400              0.842782             4.018501
# 2019-01-20 17:33:27.600              2.006143             3.622861
# 2019-01-20 17:33:27.800              0.632120             2.067285
#
#                          gyr_y_temp_mean_ws_5  gyr_y_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000             -0.771259             2.043684
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              0.708827             5.430793
# 2019-01-20 17:33:27.200             -1.585429             3.656665
# 2019-01-20 17:33:27.400             -3.071749             1.189271
# 2019-01-20 17:33:27.600             -3.200450             1.071976
# 2019-01-20 17:33:27.800             -3.029976             0.833773
#
#                          gyr_z_temp_mean_ws_5  gyr_z_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000             -0.512552             0.971453
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              7.123556             6.254808
# 2019-01-20 17:33:27.200              4.440976             5.065650
# 2019-01-20 17:33:27.400              1.950523             2.192982
# 2019-01-20 17:33:27.600              0.760034             0.532219
# 2019-01-20 17:33:27.800              0.838453             0.529146
#
#                          acc_r_temp_mean_ws_5  acc_r_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              0.971141             0.005643
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              1.084478             0.121141
# 2019-01-20 17:33:27.200              1.103662             0.106692
# 2019-01-20 17:33:27.400              1.061156             0.072672
# 2019-01-20 17:33:27.600              1.024177             0.024274
# 2019-01-20 17:33:27.800              1.029305             0.023863
#
#                          gyr_r_temp_mean_ws_5  gyr_r_temp_std_ws_5
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              3.393690             1.884665
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000             19.075515            15.269147
# 2019-01-20 17:33:27.200             11.430679            10.419379
# 2019-01-20 17:33:27.400              5.509310             2.443328
# 2019-01-20 17:33:27.600              4.877383             2.369344
# 2019-01-20 17:33:27.800              3.860940             0.790766
#
# [9009 rows x 32 columns]

# %%
df_temporal_list = []

# %%
for s in df_temporal["set"].unique():
    subset = df_temporal[df_temporal["set"] == s].copy()
    for col in predictor_columns:
        subset = NumAbs.abstract_numerical(subset, [col],ws, "mean")
        subset = NumAbs.abstract_numerical(subset, [col],ws, "std")
    df_temporal_list.append(subset)

# %%
df_temporal = pd.concat(df_temporal_list)

# %%
df_temporal
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  ...  \
# epoch (ms)                                                          ...
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30  ...
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30  ...
# ...                           ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90  ...
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90  ...
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90  ...
#
#                          gyr_x_temp_mean_ws_5  gyr_x_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              1.522572             2.602489
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000            -11.989659            18.259425
# 2019-01-20 17:33:27.200             -4.824823            12.436925
# 2019-01-20 17:33:27.400              0.842782             4.018501
# 2019-01-20 17:33:27.600              2.006143             3.622861
# 2019-01-20 17:33:27.800              0.632120             2.067285
#
#                          gyr_y_temp_mean_ws_5  gyr_y_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000             -0.771259             2.043684
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              0.708827             5.430793
# 2019-01-20 17:33:27.200             -1.585429             3.656665
# 2019-01-20 17:33:27.400             -3.071749             1.189271
# 2019-01-20 17:33:27.600             -3.200450             1.071976
# 2019-01-20 17:33:27.800             -3.029976             0.833773
#
#                          gyr_z_temp_mean_ws_5  gyr_z_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000             -0.512552             0.971453
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              7.123556             6.254808
# 2019-01-20 17:33:27.200              4.440976             5.065650
# 2019-01-20 17:33:27.400              1.950523             2.192982
# 2019-01-20 17:33:27.600              0.760034             0.532219
# 2019-01-20 17:33:27.800              0.838453             0.529146
#
#                          acc_r_temp_mean_ws_5  acc_r_temp_std_ws_5  \
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              0.971141             0.005643
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000              1.084478             0.121141
# 2019-01-20 17:33:27.200              1.103662             0.106692
# 2019-01-20 17:33:27.400              1.061156             0.072672
# 2019-01-20 17:33:27.600              1.024177             0.024274
# 2019-01-20 17:33:27.800              1.029305             0.023863
#
#                          gyr_r_temp_mean_ws_5  gyr_r_temp_std_ws_5
# epoch (ms)
# 2019-01-11 15:08:05.200                   NaN                  NaN
# 2019-01-11 15:08:05.400                   NaN                  NaN
# 2019-01-11 15:08:05.600                   NaN                  NaN
# 2019-01-11 15:08:05.800                   NaN                  NaN
# 2019-01-11 15:08:06.000              3.393690             1.884665
# ...                                       ...                  ...
# 2019-01-20 17:33:27.000             19.075515            15.269147
# 2019-01-20 17:33:27.200             11.430679            10.419379
# 2019-01-20 17:33:27.400              5.509310             2.443328
# 2019-01-20 17:33:27.600              4.877383             2.369344
# 2019-01-20 17:33:27.800              3.860940             0.790766
#
# [9009 rows x 32 columns]

# %%
df_temporal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acc_x                 9009 non-null   float64
#  1   acc_y                 9009 non-null   float64
#  2   acc_z                 9009 non-null   float64
#  3   gyr_x                 9009 non-null   float64
#  4   gyr_y                 9009 non-null   float64
#  5   gyr_z                 9009 non-null   float64
#  6   participant           9009 non-null   object
#  7   label                 9009 non-null   object
#  8   category              9009 non-null   object
#  9   set                   9009 non-null   int64
#  10  duration              9009 non-null   float64
#  11  pca_1                 9009 non-null   float64
#  12  pca_2                 9009 non-null   float64
#  13  pca_3                 9009 non-null   float64
#  14  acc_r                 9009 non-null   float64
#  15  gyr_r                 9009 non-null   float64
#  16  acc_x_temp_mean_ws_5  8645 non-null   float64
#  17  acc_x_temp_std_ws_5   8645 non-null   float64
#  18  acc_y_temp_mean_ws_5  8645 non-null   float64
#  19  acc_y_temp_std_ws_5   8645 non-null   float64
#  20  acc_z_temp_mean_ws_5  8645 non-null   float64
#  21  acc_z_temp_std_ws_5   8645 non-null   float64
#  22  gyr_x_temp_mean_ws_5  8645 non-null   float64
#  23  gyr_x_temp_std_ws_5   8645 non-null   float64
#  24  gyr_y_temp_mean_ws_5  8645 non-null   float64
#  25  gyr_y_temp_std_ws_5   8645 non-null   float64
#  26  gyr_z_temp_mean_ws_5  8645 non-null   float64
#  27  gyr_z_temp_std_ws_5   8645 non-null   float64
#  28  acc_r_temp_mean_ws_5  8645 non-null   float64
#  29  acc_r_temp_std_ws_5   8645 non-null   float64
#  30  gyr_r_temp_mean_ws_5  8645 non-null   float64
#  31  gyr_r_temp_std_ws_5   8645 non-null   float64
# dtypes: float64(28), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
subset[["acc_y","acc_y_temp_mean_ws_5","acc_y_temp_std_ws_5"]].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
subset[["gyr_y","gyr_y_temp_mean_ws_5","gyr_y_temp_std_ws_5"]].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
df_freq = df_temporal.copy().reset_index()

# %%
df_freq
# Out:
#                   epoch (ms)     acc_x     acc_y     acc_z     gyr_x  \
# 0    2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218
# 1    2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396
# 2    2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608
# 3    2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252
# 4    2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615
# ...                      ...       ...       ...       ...       ...
# 9004 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956
# 9005 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835
# 9006 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109
# 9007 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517
# 9008 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070
#
#          gyr_y     gyr_z participant  label category  ...  \
# 0     2.438803  0.937522           B  bench    heavy  ...
# 1     0.439794  0.178360           B  bench    heavy  ...
# 2    -2.083978 -1.217263           B  bench    heavy  ...
# 3    -3.456339 -0.678205           B  bench    heavy  ...
# 4    -1.194575 -1.783172           B  bench    heavy  ...
# ...        ...       ...         ...    ...      ...  ...
# 9004 -4.019557  0.196986           E    row   medium  ...
# 9005 -2.660315  1.584934           E    row   medium  ...
# 9006 -2.022091  1.155930           E    row   medium  ...
# 9007 -2.427441  0.279918           E    row   medium  ...
# 9008 -4.020475  0.974497           E    row   medium  ...
#
#       gyr_x_temp_mean_ws_5  gyr_x_temp_std_ws_5  gyr_y_temp_mean_ws_5  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                 1.522572             2.602489             -0.771259
# ...                    ...                  ...                   ...
# 9004            -11.989659            18.259425              0.708827
# 9005             -4.824823            12.436925             -1.585429
# 9006              0.842782             4.018501             -3.071749
# 9007              2.006143             3.622861             -3.200450
# 9008              0.632120             2.067285             -3.029976
#
#       gyr_y_temp_std_ws_5  gyr_z_temp_mean_ws_5  gyr_z_temp_std_ws_5  \
# 0                     NaN                   NaN                  NaN
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 4                2.043684             -0.512552             0.971453
# ...                   ...                   ...                  ...
# 9004             5.430793              7.123556             6.254808
# 9005             3.656665              4.440976             5.065650
# 9006             1.189271              1.950523             2.192982
# 9007             1.071976              0.760034             0.532219
# 9008             0.833773              0.838453             0.529146
#
#       acc_r_temp_mean_ws_5  acc_r_temp_std_ws_5  gyr_r_temp_mean_ws_5  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                 0.971141             0.005643              3.393690
# ...                    ...                  ...                   ...
# 9004              1.084478             0.121141             19.075515
# 9005              1.103662             0.106692             11.430679
# 9006              1.061156             0.072672              5.509310
# 9007              1.024177             0.024274              4.877383
# 9008              1.029305             0.023863              3.860940
#
#       gyr_r_temp_std_ws_5
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                1.884665
# ...                   ...
# 9004            15.269147
# 9005            10.419379
# 9006             2.443328
# 9007             2.369344
# 9008             0.790766
#
# [9009 rows x 33 columns]

# %%
from FrequencyAbstraction import FourierTransformation

# %%
FreqAbs = FourierTransformation()

# %%
fs = int(1000 /200)

# %%
ws = int(2000 / 200)

# %%
fs
# Out:
# 5

# %%
ws
# Out:
# 10

# %%
ws = int(2800 / 200)

# %%
ws
# Out:
# 14

# %%
df_freq = FreqAbs.abstract_frequency(df_freq,["acc_y"], ws, fs)

# %%
df_freq
# Out:
#                   epoch (ms)     acc_x     acc_y     acc_z     gyr_x  \
# 0    2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218
# 1    2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396
# 2    2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608
# 3    2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252
# 4    2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615
# ...                      ...       ...       ...       ...       ...
# 9004 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956
# 9005 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835
# 9006 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109
# 9007 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517
# 9008 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070
#
#          gyr_y     gyr_z participant  label category  ...  \
# 0     2.438803  0.937522           B  bench    heavy  ...
# 1     0.439794  0.178360           B  bench    heavy  ...
# 2    -2.083978 -1.217263           B  bench    heavy  ...
# 3    -3.456339 -0.678205           B  bench    heavy  ...
# 4    -1.194575 -1.783172           B  bench    heavy  ...
# ...        ...       ...         ...    ...      ...  ...
# 9004 -4.019557  0.196986           E    row   medium  ...
# 9005 -2.660315  1.584934           E    row   medium  ...
# 9006 -2.022091  1.155930           E    row   medium  ...
# 9007 -2.427441  0.279918           E    row   medium  ...
# 9008 -4.020475  0.974497           E    row   medium  ...
#
#       acc_y_freq_weighted  acc_y_pse  acc_y_freq_0.0_Hz_ws_14  \
# 0                     NaN        NaN                      NaN
# 1                     NaN        NaN                      NaN
# 2                     NaN        NaN                      NaN
# 3                     NaN        NaN                      NaN
# 4                     NaN        NaN                      NaN
# ...                   ...        ...                      ...
# 9004            -0.366246   0.080086               -15.086721
# 9005            -0.189618   0.098206               -15.605886
# 9006             0.083718   0.054012               -15.790817
# 9007             0.116557   0.041741               -15.550088
# 9008            -0.050902   0.055024               -15.383518
#
#       acc_y_freq_0.357_Hz_ws_14  acc_y_freq_0.714_Hz_ws_14  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 9004                   0.169773                   1.260702
# 9005                  -0.499724                   1.034515
# 9006                  -0.732594                   0.519170
# 9007                  -0.433942                   0.006282
# 9008                  -0.148817                  -0.640036
#
#       acc_y_freq_1.071_Hz_ws_14  acc_y_freq_1.429_Hz_ws_14  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 9004                   0.908251                   0.370038
# 9005                  -1.036798                   0.960714
# 9006                  -1.087010                  -0.032387
# 9007                   0.624310                  -0.794175
# 9008                   1.283599                  -0.059726
#
#       acc_y_freq_1.786_Hz_ws_14  acc_y_freq_2.143_Hz_ws_14  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 9004                   0.284737                   0.272604
# 9005                   0.363849                   0.279607
# 9006                  -0.036956                  -0.056240
# 9007                  -0.262326                  -0.198431
# 9008                  -0.024733                   0.001820
#
#       acc_y_freq_2.5_Hz_ws_14
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 9004                 0.270130
# 9005                 0.252243
# 9006                -0.063536
# 9007                -0.178484
# 9008                 0.009044
#
# [9009 rows x 44 columns]

# %%
df_freq.columns
# Out:
# Index(['epoch (ms)', 'acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z',
#        'participant', 'label', 'category', 'set', 'duration', 'pca_1', 'pca_2',
#        'pca_3', 'acc_r', 'gyr_r', 'acc_x_temp_mean_ws_5',
#        'acc_x_temp_std_ws_5', 'acc_y_temp_mean_ws_5', 'acc_y_temp_std_ws_5',
#        'acc_z_temp_mean_ws_5', 'acc_z_temp_std_ws_5', 'gyr_x_temp_mean_ws_5',
#        'gyr_x_temp_std_ws_5', 'gyr_y_temp_mean_ws_5', 'gyr_y_temp_std_ws_5',
#        'gyr_z_temp_mean_ws_5', 'gyr_z_temp_std_ws_5', 'acc_r_temp_mean_ws_5',
#        'acc_r_temp_std_ws_5', 'gyr_r_temp_mean_ws_5', 'gyr_r_temp_std_ws_5',
#        'acc_y_max_freq', 'acc_y_freq_weighted', 'acc_y_pse',
#        'acc_y_freq_0.0_Hz_ws_14', 'acc_y_freq_0.357_Hz_ws_14',
#        'acc_y_freq_0.714_Hz_ws_14', 'acc_y_freq_1.071_Hz_ws_14',
#        'acc_y_freq_1.429_Hz_ws_14', 'acc_y_freq_1.786_Hz_ws_14',
#        'acc_y_freq_2.143_Hz_ws_14', 'acc_y_freq_2.5_Hz_ws_14'],
#       dtype='object')

# %%
subset = df_freq[df_freq["set"] == 15]

# %%
subset[["acc_y"]].plot()
# Out:
# <Axes: >

# %%
subset[
    [
    "acc_y_max_freq",
    "acc_y_freq_weighted",
    "acc_y_pse",
    "acc_y_freq_1.429_Hz_ws_14",
    "acc_y_freq_2.5_Hz_ws_14",
    ]
].plot()
# Out:
# <Axes: >

# %%
df_freq_list = []

# %%
for s in df_freq["set"].unique():
    print(f"Applying Fourier transformations to set {s}")
    subset = df_freq[df_freq["set"] == s].reset_index(drop=True).copy()
    subset = FreqAbs.abstract_frequency(subset,predictor_columns,ws,fs)
    df_freq_list.append(subset)
# Out:
# Applying Fourier transformations to set 30
# Applying Fourier transformations to set 1
# Applying Fourier transformations to set 31
# Applying Fourier transformations to set 3
# Applying Fourier transformations to set 9
# Applying Fourier transformations to set 32
# Applying Fourier transformations to set 10
# Applying Fourier transformations to set 33
# Applying Fourier transformations to set 11
# Applying Fourier transformations to set 34
# Applying Fourier transformations to set 35
# Applying Fourier transformations to set 15
# Applying Fourier transformations to set 36
# Applying Fourier transformations to set 16
# Applying Fourier transformations to set 37
# Applying Fourier transformations to set 17
# Applying Fourier transformations to set 27
# Applying Fourier transformations to set 38
# Applying Fourier transformations to set 28
# Applying Fourier transformations to set 29
# Applying Fourier transformations to set 6
# Applying Fourier transformations to set 65
# Applying Fourier transformations to set 67
# Applying Fourier transformations to set 73
# Applying Fourier transformations to set 4
# Applying Fourier transformations to set 2
# Applying Fourier transformations to set 39
# Applying Fourier transformations to set 40
# Applying Fourier transformations to set 12
# Applying Fourier transformations to set 41
# Applying Fourier transformations to set 13
# Applying Fourier transformations to set 45
# Applying Fourier transformations to set 14
# Applying Fourier transformations to set 46
# Applying Fourier transformations to set 51
# Applying Fourier transformations to set 22
# Applying Fourier transformations to set 47
# Applying Fourier transformations to set 23
# Applying Fourier transformations to set 49
# Applying Fourier transformations to set 68
# Applying Fourier transformations to set 66
# Applying Fourier transformations to set 76
# Applying Fourier transformations to set 77
# Applying Fourier transformations to set 78
# Applying Fourier transformations to set 52
# Applying Fourier transformations to set 83
# Applying Fourier transformations to set 48
# Applying Fourier transformations to set 85
# Applying Fourier transformations to set 50
# Applying Fourier transformations to set 24
# Applying Fourier transformations to set 53
# Applying Fourier transformations to set 25
# Applying Fourier transformations to set 54
# Applying Fourier transformations to set 26
# Applying Fourier transformations to set 55
# Applying Fourier transformations to set 7
# Applying Fourier transformations to set 42
# Applying Fourier transformations to set 8
# Applying Fourier transformations to set 43
# Applying Fourier transformations to set 5
# Applying Fourier transformations to set 44
# Applying Fourier transformations to set 84
# Applying Fourier transformations to set 86
# Applying Fourier transformations to set 92
# Applying Fourier transformations to set 93
# Applying Fourier transformations to set 74
# Applying Fourier transformations to set 75
# Applying Fourier transformations to set 72
# Applying Fourier transformations to set 63
# Applying Fourier transformations to set 64
# Applying Fourier transformations to set 62
# Applying Fourier transformations to set 56
# Applying Fourier transformations to set 57
# Applying Fourier transformations to set 18
# Applying Fourier transformations to set 58
# Applying Fourier transformations to set 20
# Applying Fourier transformations to set 59
# Applying Fourier transformations to set 60
# Applying Fourier transformations to set 61
# Applying Fourier transformations to set 69
# Applying Fourier transformations to set 70
# Applying Fourier transformations to set 19
# Applying Fourier transformations to set 71
# Applying Fourier transformations to set 21
# Applying Fourier transformations to set 87
# Applying Fourier transformations to set 89
# Applying Fourier transformations to set 91
# Applying Fourier transformations to set 80
# Applying Fourier transformations to set 82
# Applying Fourier transformations to set 88
# Applying Fourier transformations to set 90

# %%
pd.concat(df_freq_list)
# Out:
#                 epoch (ms)     acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# 0  2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 1  2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2  2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 3  2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 4  2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ..                     ...       ...       ...       ...       ...       ...
# 93 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 94 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 95 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 96 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 97 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#        gyr_z participant  label category  ...  gyr_r_freq_weighted  gyr_r_pse  \
# 0   0.937522           B  bench    heavy  ...                  NaN        NaN
# 1   0.178360           B  bench    heavy  ...                  NaN        NaN
# 2  -1.217263           B  bench    heavy  ...                  NaN        NaN
# 3  -0.678205           B  bench    heavy  ...                  NaN        NaN
# 4  -1.783172           B  bench    heavy  ...                  NaN        NaN
# ..       ...         ...    ...      ...  ...                  ...        ...
# 93  0.196986           E    row   medium  ...            -0.255402   0.238607
# 94  1.584934           E    row   medium  ...             0.536997   0.660463
# 95  1.155930           E    row   medium  ...             0.633179   0.577277
# 96  0.279918           E    row   medium  ...             0.011089   0.612936
# 97  0.974497           E    row   medium  ...             0.140562   0.333870
#
#     gyr_r_freq_0.0_Hz_ws_14  gyr_r_freq_0.357_Hz_ws_14  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ..                      ...                        ...
# 93               319.521621                 -34.907878
# 94               308.391215                 -44.886326
# 95               267.731227                 -73.117861
# 96               240.957375                 -72.505797
# 97               235.498209                 -37.570166
#
#     gyr_r_freq_0.714_Hz_ws_14  gyr_r_freq_1.071_Hz_ws_14  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 93                  31.861740                   9.784884
# 94                  66.358365                  78.568468
# 95                  40.866650                  37.338879
# 96                  11.076672                 -23.105359
# 97                  -2.922213                 -26.531899
#
#     gyr_r_freq_1.429_Hz_ws_14  gyr_r_freq_1.786_Hz_ws_14  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 93                   1.149502                 -51.406834
# 94                 -20.114545                  64.769560
# 95                  18.436116                  18.097675
# 96                  59.718965                 -28.820321
# 97                  -3.576289                  40.226081
#
#     gyr_r_freq_2.143_Hz_ws_14  gyr_r_freq_2.5_Hz_ws_14
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 93                  -1.543486                 0.948401
# 94                  14.905502                 8.625034
# 95                  21.450904                33.080361
# 96                  12.706694                -6.491219
# 97                 -10.820358                11.732102
#
# [9009 rows x 121 columns]

# %%
df_freq= pd.concat(df_freq_list).set_index("epoch (ms)", drop=True)

# %%
df_freq
# Out:
#                             acc_x     acc_y     acc_z     gyr_x     gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013503  0.977003 -0.071001 -1.886218  2.438803
# 2019-01-11 15:08:05.400  0.008515  0.973169 -0.066481 -0.367396  0.439794
# 2019-01-11 15:08:05.600 -0.008450  0.966879 -0.071895  4.320608 -2.083978
# 2019-01-11 15:08:05.800 -0.024359  0.962244 -0.084774  4.737252 -3.456339
# 2019-01-11 15:08:06.000 -0.022092  0.959572 -0.096776  0.808615 -1.194575
# ...                           ...       ...       ...       ...       ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545  2.032956 -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530 -2.967835 -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951 -0.043109 -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327  3.033517 -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316  1.105070 -4.020475
#
#                             gyr_z participant  label category  set  ...  \
# epoch (ms)                                                          ...
# 2019-01-11 15:08:05.200  0.937522           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.400  0.178360           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.600 -1.217263           B  bench    heavy   30  ...
# 2019-01-11 15:08:05.800 -0.678205           B  bench    heavy   30  ...
# 2019-01-11 15:08:06.000 -1.783172           B  bench    heavy   30  ...
# ...                           ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:27.000  0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.200  1.584934           E    row   medium   90  ...
# 2019-01-20 17:33:27.400  1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.600  0.279918           E    row   medium   90  ...
# 2019-01-20 17:33:27.800  0.974497           E    row   medium   90  ...
#
#                          gyr_r_freq_weighted  gyr_r_pse  \
# epoch (ms)
# 2019-01-11 15:08:05.200                  NaN        NaN
# 2019-01-11 15:08:05.400                  NaN        NaN
# 2019-01-11 15:08:05.600                  NaN        NaN
# 2019-01-11 15:08:05.800                  NaN        NaN
# 2019-01-11 15:08:06.000                  NaN        NaN
# ...                                      ...        ...
# 2019-01-20 17:33:27.000            -0.255402   0.238607
# 2019-01-20 17:33:27.200             0.536997   0.660463
# 2019-01-20 17:33:27.400             0.633179   0.577277
# 2019-01-20 17:33:27.600             0.011089   0.612936
# 2019-01-20 17:33:27.800             0.140562   0.333870
#
#                          gyr_r_freq_0.0_Hz_ws_14  gyr_r_freq_0.357_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:05.200                      NaN                        NaN
# 2019-01-11 15:08:05.400                      NaN                        NaN
# 2019-01-11 15:08:05.600                      NaN                        NaN
# 2019-01-11 15:08:05.800                      NaN                        NaN
# 2019-01-11 15:08:06.000                      NaN                        NaN
# ...                                          ...                        ...
# 2019-01-20 17:33:27.000               319.521621                 -34.907878
# 2019-01-20 17:33:27.200               308.391215                 -44.886326
# 2019-01-20 17:33:27.400               267.731227                 -73.117861
# 2019-01-20 17:33:27.600               240.957375                 -72.505797
# 2019-01-20 17:33:27.800               235.498209                 -37.570166
#
#                          gyr_r_freq_0.714_Hz_ws_14  gyr_r_freq_1.071_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:05.200                        NaN                        NaN
# 2019-01-11 15:08:05.400                        NaN                        NaN
# 2019-01-11 15:08:05.600                        NaN                        NaN
# 2019-01-11 15:08:05.800                        NaN                        NaN
# 2019-01-11 15:08:06.000                        NaN                        NaN
# ...                                            ...                        ...
# 2019-01-20 17:33:27.000                  31.861740                   9.784884
# 2019-01-20 17:33:27.200                  66.358365                  78.568468
# 2019-01-20 17:33:27.400                  40.866650                  37.338879
# 2019-01-20 17:33:27.600                  11.076672                 -23.105359
# 2019-01-20 17:33:27.800                  -2.922213                 -26.531899
#
#                          gyr_r_freq_1.429_Hz_ws_14  gyr_r_freq_1.786_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:05.200                        NaN                        NaN
# 2019-01-11 15:08:05.400                        NaN                        NaN
# 2019-01-11 15:08:05.600                        NaN                        NaN
# 2019-01-11 15:08:05.800                        NaN                        NaN
# 2019-01-11 15:08:06.000                        NaN                        NaN
# ...                                            ...                        ...
# 2019-01-20 17:33:27.000                   1.149502                 -51.406834
# 2019-01-20 17:33:27.200                 -20.114545                  64.769560
# 2019-01-20 17:33:27.400                  18.436116                  18.097675
# 2019-01-20 17:33:27.600                  59.718965                 -28.820321
# 2019-01-20 17:33:27.800                  -3.576289                  40.226081
#
#                          gyr_r_freq_2.143_Hz_ws_14  gyr_r_freq_2.5_Hz_ws_14
# epoch (ms)
# 2019-01-11 15:08:05.200                        NaN                      NaN
# 2019-01-11 15:08:05.400                        NaN                      NaN
# 2019-01-11 15:08:05.600                        NaN                      NaN
# 2019-01-11 15:08:05.800                        NaN                      NaN
# 2019-01-11 15:08:06.000                        NaN                      NaN
# ...                                            ...                      ...
# 2019-01-20 17:33:27.000                  -1.543486                 0.948401
# 2019-01-20 17:33:27.200                  14.905502                 8.625034
# 2019-01-20 17:33:27.400                  21.450904                33.080361
# 2019-01-20 17:33:27.600                  12.706694                -6.491219
# 2019-01-20 17:33:27.800                 -10.820358                11.732102
#
# [9009 rows x 120 columns]

# %%
df_freq.dropna()
# Out:
#                             acc_x     acc_y     acc_z      gyr_x      gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:08.000 -0.172350  0.909033 -0.168556 -27.895242 -10.831760
# 2019-01-11 15:08:08.200 -0.075541  0.854894 -0.094507 -17.787623  -7.152388
# 2019-01-11 15:08:08.400 -0.024777  0.860474 -0.059254  -2.040040  -1.316930
# 2019-01-11 15:08:08.600 -0.039468  0.947898 -0.047164   1.731909  -0.126808
# 2019-01-11 15:08:08.800 -0.063378  0.997048 -0.033869   1.164754  -1.844231
# ...                           ...       ...       ...        ...        ...
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545   2.032956  -4.019557
# 2019-01-20 17:33:27.200 -0.041403 -1.053448 -0.064530  -2.967835  -2.660315
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951  -0.043109  -2.022091
# 2019-01-20 17:33:27.600 -0.050572 -1.010599 -0.060327   3.033517  -2.427441
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316   1.105070  -4.020475
#
#                              gyr_z participant  label category  set  ...  \
# epoch (ms)                                                           ...
# 2019-01-11 15:08:08.000  26.285743           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.200  16.679304           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.400   1.986210           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.600  -3.356740           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.800  -1.240332           B  bench    heavy   30  ...
# ...                            ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:27.000   0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.200   1.584934           E    row   medium   90  ...
# 2019-01-20 17:33:27.400   1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.600   0.279918           E    row   medium   90  ...
# 2019-01-20 17:33:27.800   0.974497           E    row   medium   90  ...
#
#                          gyr_r
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                 -47.609218                 -37.827325
# 2019-01-20 17:33:26.600                  27.460451                  82.477003
# 2019-01-20 17:33:27.000                   1.149502                 -51.406834
# 2019-01-20 17:33:27.400                  18.436116                  18.097675
# 2019-01-20 17:33:27.800                  -3.576289                  40.226081
#
#                          gyr_r_freq_2.143_Hz_ws_14  gyr_r_freq_2.5_Hz_ws_14
# epoch (ms)
# 2019-01-11 15:08:08.000                 -56.937517                -9.887314
# 2019-01-11 15:08:08.400                   5.797033                -2.207473
# 2019-01-11 15:08:08.800                  42.767778               -11.602442
# 2019-01-11 15:08:09.200                  26.990522                -9.999852
# 2019-01-11 15:08:09.600                 -35.551747               -33.538487
# ...                                            ...                      ...
# 2019-01-20 17:33:26.200                 -17.620149               -36.551825
# 2019-01-20 17:33:26.600                  22.715838                 9.757813
# 2019-01-20 17:33:27.000                  -1.543486                 0.948401
# 2019-01-20 17:33:27.400                  21.450904                33.080361
# 2019-01-20 17:33:27.800                 -10.820358                11.732102
#
# [3868 rows x 120 columns]

# %%
from sklearn.cluster import KMeans

# %%
df_cluster = df_freq.copy()

# %%
cluster_columns = ["acc_x","acc_y","acc_z"]
k_values = range(2,10)
inertias = []

# %%
cluster_columns
# Out:
# ['acc_x', 'acc_y', 'acc_z']

# %%
df_cluster[cluster_columns]
# Out:
#                             acc_x     acc_y     acc_z
# epoch (ms)
# 2019-01-11 15:08:08.000 -0.172350  0.909033 -0.168556
# 2019-01-11 15:08:08.400 -0.024777  0.860474 -0.059254
# 2019-01-11 15:08:08.800 -0.063378  0.997048 -0.033869
# 2019-01-11 15:08:09.200 -0.044993  0.971809 -0.038011
# 2019-01-11 15:08:09.600 -0.046925  0.911220 -0.056463
# ...                           ...       ...       ...
# 2019-01-20 17:33:26.200  0.063910 -0.952114  0.107673
# 2019-01-20 17:33:26.600 -0.024266 -1.193314 -0.109309
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316
#
# [3868 rows x 3 columns]

# %%
k_values = range(2,10)

# %%
inertias = []

# %%
for k in k_values:
    subset = df_cluster[cluster_columns]
    kmeans = KMeans(n_clusters=k,n_init=20,random_state=0)
    cluster_labels = kmeans.fit_predict(subset)
    inertias.append(kmeans.inertia_)

# %%
inertias
# Out:
# [888.2145379895427,
#  513.7868949414761,
#  315.9388838213685,
#  234.30076852770597,
#  209.18733836503517,
#  185.88222426924662,
#  165.53928247652053,
#  147.17977465890473]

# %%
plt.figure(figsize=(10, 10))
plt.plot(k_values, inertias)
plt.xlabel("k")
plt.ylabel("Sum of squared distances")
plt.show()

# %%
kmeans = KMeans(n_clusters=k,n_init=20,random_state=0)

# %%
subset = df_cluster[cluster_columns]

# %%
df_cluster["cluster"] = kmeans.fit_predict(subset)

# %%
df_cluster
# Out:
#                             acc_x     acc_y     acc_z      gyr_x      gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:08.000 -0.172350  0.909033 -0.168556 -27.895242 -10.831760
# 2019-01-11 15:08:08.400 -0.024777  0.860474 -0.059254  -2.040040  -1.316930
# 2019-01-11 15:08:08.800 -0.063378  0.997048 -0.033869   1.164754  -1.844231
# 2019-01-11 15:08:09.200 -0.044993  0.971809 -0.038011   2.469483  -3.482648
# 2019-01-11 15:08:09.600 -0.046925  0.911220 -0.056463   8.471911   4.745072
# ...                           ...       ...       ...        ...        ...
# 2019-01-20 17:33:26.200  0.063910 -0.952114  0.107673 -38.792016   8.810964
# 2019-01-20 17:33:26.600 -0.024266 -1.193314 -0.109309  -2.783290  -1.783932
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545   2.032956  -4.019557
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951  -0.043109  -2.022091
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316   1.105070  -4.020475
#
#                              gyr_z participant  label category  set  ...  \
# epoch (ms)                                                           ...
# 2019-01-11 15:08:08.000  26.285743           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.400   1.986210           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.800  -1.240332           B  bench    heavy   30  ...
# 2019-01-11 15:08:09.200   3.563210           B  bench    heavy   30  ...
# 2019-01-11 15:08:09.600  -8.708681           B  bench    heavy   30  ...
# ...                            ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:26.200  14.997831           E    row   medium   90  ...
# 2019-01-20 17:33:26.600   6.232364           E    row   medium   90  ...
# 2019-01-20 17:33:27.000   0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.400   1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.800   0.974497           E    row   medium   90  ...
#
#                          gyr_r_pse  gyr_r_freq_0.0_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000   0.404506               241.915837
# 2019-01-11 15:08:08.400   0.376805               266.641927
# 2019-01-11 15:08:08.800   0.508919               262.078311
# 2019-01-11 15:08:09.200   0.492961               256.245567
# 2019-01-11 15:08:09.600   0.363189               214.663711
# ...                            ...                      ...
# 2019-01-20 17:33:26.200   0.350704               368.429928
# 2019-01-20 17:33:26.600   0.324461               379.719977
# 2019-01-20 17:33:27.000   0.238607               319.521621
# 2019-01-20 17:33:27.400   0.577277               267.731227
# 2019-01-20 17:33:27.800   0.333870               235.498209
#
#                          gyr_r_freq_0.357_Hz_ws_14  gyr_r_freq_0.714_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                 -32.414519                  17.800054
# 2019-01-11 15:08:08.400                 -45.027971                 -65.743054
# 2019-01-11 15:08:08.800                 -56.234625                 -30.091473
# 2019-01-11 15:08:09.200                 -31.989318                  69.348370
# 2019-01-11 15:08:09.600                 -12.227055                  13.687545
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                  29.216316                 -57.045603
# 2019-01-20 17:33:26.600                  39.879652                 -21.517667
# 2019-01-20 17:33:27.000                 -34.907878                  31.861740
# 2019-01-20 17:33:27.400                 -73.117861                  40.866650
# 2019-01-20 17:33:27.800                 -37.570166                  -2.922213
#
#                          gyr_r_freq_1.071_Hz_ws_14  gyr_r_freq_1.429_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                  -7.090627                 -23.559585
# 2019-01-11 15:08:08.400                 -12.016695                   8.716330
# 2019-01-11 15:08:08.800                   3.458370                 -13.917311
# 2019-01-11 15:08:09.200                   3.624009                  17.424045
# 2019-01-11 15:08:09.600                  10.833066                   6.326124
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                  10.239165                 -47.609218
# 2019-01-20 17:33:26.600                 -13.542762                  27.460451
# 2019-01-20 17:33:27.000                   9.784884                   1.149502
# 2019-01-20 17:33:27.400                  37.338879                  18.436116
# 2019-01-20 17:33:27.800                 -26.531899                  -3.576289
#
#                          gyr_r_freq_1.786_Hz_ws_14  gyr_r_freq_2.143_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                  15.300362                 -56.937517
# 2019-01-11 15:08:08.400                  14.278175                   5.797033
# 2019-01-11 15:08:08.800                 -48.217504                  42.767778
# 2019-01-11 15:08:09.200                  36.328368                  26.990522
# 2019-01-11 15:08:09.600                  25.453064                 -35.551747
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                 -37.827325                 -17.620149
# 2019-01-20 17:33:26.600                  82.477003                  22.715838
# 2019-01-20 17:33:27.000                 -51.406834                  -1.543486
# 2019-01-20 17:33:27.400                  18.097675                  21.450904
# 2019-01-20 17:33:27.800                  40.226081                 -10.820358
#
#                          gyr_r_freq_2.5_Hz_ws_14  cluster
# epoch (ms)
# 2019-01-11 15:08:08.000                -9.887314        7
# 2019-01-11 15:08:08.400                -2.207473        0
# 2019-01-11 15:08:08.800               -11.602442        0
# 2019-01-11 15:08:09.200                -9.999852        0
# 2019-01-11 15:08:09.600               -33.538487        0
# ...                                          ...      ...
# 2019-01-20 17:33:26.200               -36.551825        1
# 2019-01-20 17:33:26.600                 9.757813        4
# 2019-01-20 17:33:27.000                 0.948401        4
# 2019-01-20 17:33:27.400                33.080361        4
# 2019-01-20 17:33:27.800                11.732102        4
#
# [3868 rows x 121 columns]

# %%
kmeans = KMeans(n_clusters=5,n_init=20,random_state=0)

# %%
subset = df_cluster[cluster_columns]

# %%
df_cluster["cluster"] = kmeans.fit_predict(subset)

# %%
df_cluster
# Out:
#                             acc_x     acc_y     acc_z      gyr_x      gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:08.000 -0.172350  0.909033 -0.168556 -27.895242 -10.831760
# 2019-01-11 15:08:08.400 -0.024777  0.860474 -0.059254  -2.040040  -1.316930
# 2019-01-11 15:08:08.800 -0.063378  0.997048 -0.033869   1.164754  -1.844231
# 2019-01-11 15:08:09.200 -0.044993  0.971809 -0.038011   2.469483  -3.482648
# 2019-01-11 15:08:09.600 -0.046925  0.911220 -0.056463   8.471911   4.745072
# ...                           ...       ...       ...        ...        ...
# 2019-01-20 17:33:26.200  0.063910 -0.952114  0.107673 -38.792016   8.810964
# 2019-01-20 17:33:26.600 -0.024266 -1.193314 -0.109309  -2.783290  -1.783932
# 2019-01-20 17:33:27.000 -0.043276 -0.988153 -0.062545   2.032956  -4.019557
# 2019-01-20 17:33:27.400 -0.048048 -1.044737 -0.065951  -0.043109  -2.022091
# 2019-01-20 17:33:27.800 -0.044005 -1.035004 -0.059316   1.105070  -4.020475
#
#                              gyr_z participant  label category  set  ...  \
# epoch (ms)                                                           ...
# 2019-01-11 15:08:08.000  26.285743           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.400   1.986210           B  bench    heavy   30  ...
# 2019-01-11 15:08:08.800  -1.240332           B  bench    heavy   30  ...
# 2019-01-11 15:08:09.200   3.563210           B  bench    heavy   30  ...
# 2019-01-11 15:08:09.600  -8.708681           B  bench    heavy   30  ...
# ...                            ...         ...    ...      ...  ...  ...
# 2019-01-20 17:33:26.200  14.997831           E    row   medium   90  ...
# 2019-01-20 17:33:26.600   6.232364           E    row   medium   90  ...
# 2019-01-20 17:33:27.000   0.196986           E    row   medium   90  ...
# 2019-01-20 17:33:27.400   1.155930           E    row   medium   90  ...
# 2019-01-20 17:33:27.800   0.974497           E    row   medium   90  ...
#
#                          gyr_r_pse  gyr_r_freq_0.0_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000   0.404506               241.915837
# 2019-01-11 15:08:08.400   0.376805               266.641927
# 2019-01-11 15:08:08.800   0.508919               262.078311
# 2019-01-11 15:08:09.200   0.492961               256.245567
# 2019-01-11 15:08:09.600   0.363189               214.663711
# ...                            ...                      ...
# 2019-01-20 17:33:26.200   0.350704               368.429928
# 2019-01-20 17:33:26.600   0.324461               379.719977
# 2019-01-20 17:33:27.000   0.238607               319.521621
# 2019-01-20 17:33:27.400   0.577277               267.731227
# 2019-01-20 17:33:27.800   0.333870               235.498209
#
#                          gyr_r_freq_0.357_Hz_ws_14  gyr_r_freq_0.714_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                 -32.414519                  17.800054
# 2019-01-11 15:08:08.400                 -45.027971                 -65.743054
# 2019-01-11 15:08:08.800                 -56.234625                 -30.091473
# 2019-01-11 15:08:09.200                 -31.989318                  69.348370
# 2019-01-11 15:08:09.600                 -12.227055                  13.687545
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                  29.216316                 -57.045603
# 2019-01-20 17:33:26.600                  39.879652                 -21.517667
# 2019-01-20 17:33:27.000                 -34.907878                  31.861740
# 2019-01-20 17:33:27.400                 -73.117861                  40.866650
# 2019-01-20 17:33:27.800                 -37.570166                  -2.922213
#
#                          gyr_r_freq_1.071_Hz_ws_14  gyr_r_freq_1.429_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                  -7.090627                 -23.559585
# 2019-01-11 15:08:08.400                 -12.016695                   8.716330
# 2019-01-11 15:08:08.800                   3.458370                 -13.917311
# 2019-01-11 15:08:09.200                   3.624009                  17.424045
# 2019-01-11 15:08:09.600                  10.833066                   6.326124
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                  10.239165                 -47.609218
# 2019-01-20 17:33:26.600                 -13.542762                  27.460451
# 2019-01-20 17:33:27.000                   9.784884                   1.149502
# 2019-01-20 17:33:27.400                  37.338879                  18.436116
# 2019-01-20 17:33:27.800                 -26.531899                  -3.576289
#
#                          gyr_r_freq_1.786_Hz_ws_14  gyr_r_freq_2.143_Hz_ws_14  \
# epoch (ms)
# 2019-01-11 15:08:08.000                  15.300362                 -56.937517
# 2019-01-11 15:08:08.400                  14.278175                   5.797033
# 2019-01-11 15:08:08.800                 -48.217504                  42.767778
# 2019-01-11 15:08:09.200                  36.328368                  26.990522
# 2019-01-11 15:08:09.600                  25.453064                 -35.551747
# ...                                            ...                        ...
# 2019-01-20 17:33:26.200                 -37.827325                 -17.620149
# 2019-01-20 17:33:26.600                  82.477003                  22.715838
# 2019-01-20 17:33:27.000                 -51.406834                  -1.543486
# 2019-01-20 17:33:27.400                  18.097675                  21.450904
# 2019-01-20 17:33:27.800                  40.226081                 -10.820358
#
#                          gyr_r_freq_2.5_Hz_ws_14  cluster
# epoch (ms)
# 2019-01-11 15:08:08.000                -9.887314        1
# 2019-01-11 15:08:08.400                -2.207473        1
# 2019-01-11 15:08:08.800               -11.602442        1
# 2019-01-11 15:08:09.200                -9.999852        1
# 2019-01-11 15:08:09.600               -33.538487        1
# ...                                          ...      ...
# 2019-01-20 17:33:26.200               -36.551825        3
# 2019-01-20 17:33:26.600                 9.757813        0
# 2019-01-20 17:33:27.000                 0.948401        0
# 2019-01-20 17:33:27.400                33.080361        0
# 2019-01-20 17:33:27.800                11.732102        0
#
# [3868 rows x 121 columns]

# %%
#plot clusters
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(projection="3d")
for c in df_cluster["cluster"].unique():
    subset = df_cluster[df_cluster["cluster"] == c]
    ax.scatter(subset["acc_x"],subset["acc_y"],subset["acc_z"],label=c)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(projection="3d")
for c in df_cluster["label"].unique():
    subset = df_cluster[df_cluster["label"] == c]
    ax.scatter(subset["acc_x"],subset["acc_y"],subset["acc_z"],label=c)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
plt.legend()
plt.show()

# %%
df_cluster.to_pickle("../../data/interim/03_data_features.pkl")
